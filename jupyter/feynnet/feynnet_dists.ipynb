# %%
mloc = "/eos/uscms/store/user/srosenzw/weaver/models/exp_sixb_official/feynnet_ranker_6b/20230731_7d266883bbfb88fe4e226783a7d1c9db_ranger_lr0.0047_batch2000_withbkg/predict_output/2018/maxbtag"

# %%
tree1 = SixB("/eos/uscms/store/user/srosenzw/sixb/ntuples/Summer2018UL/maxbtag/Official_NMSSM/NMSSM_XToYHTo6B_MX-450_MY-300_TuneCP5_13TeV-madgraph-pythia8/ntuple.root", feyn=f"{mloc}/NMSSM_XToYHTo6B_MX-450_MY-300_TuneCP5_13TeV-madgraph-pythia8.root")
tree2 = SixB("/eos/uscms/store/user/srosenzw/sixb/ntuples/Summer2018UL/maxbtag/Official_NMSSM/NMSSM_XToYHTo6B_MX-700_MY-400_TuneCP5_13TeV-madgraph-pythia8/ntuple.root", feyn=f"{mloc}/NMSSM_XToYHTo6B_MX-700_MY-400_TuneCP5_13TeV-madgraph-pythia8.root")
tree3 = SixB("/eos/uscms/store/user/srosenzw/sixb/ntuples/Summer2018UL/maxbtag/Official_NMSSM/NMSSM_XToYHTo6B_MX-1000_MY-600_TuneCP5_13TeV-madgraph-pythia8/ntuple.root", feyn=f"{mloc}/NMSSM_XToYHTo6B_MX-1000_MY-600_TuneCP5_13TeV-madgraph-pythia8.root")
tree4 = SixB("/eos/uscms/store/user/srosenzw/sixb/ntuples/Summer2018UL/maxbtag/Official_NMSSM/NMSSM_XToYHTo6B_MX-1200_MY-250_TuneCP5_13TeV-madgraph-pythia8/ntuple.root", feyn=f"{mloc}/NMSSM_XToYHTo6B_MX-1200_MY-250_TuneCP5_13TeV-madgraph-pythia8.root")
tree5 = SixB("/eos/uscms/store/user/srosenzw/sixb/ntuples/Summer2018UL/maxbtag/Official_NMSSM/NMSSM_XToYHTo6B_MX-1200_MY-900_TuneCP5_13TeV-madgraph-pythia8/ntuple.root", feyn=f"{mloc}/NMSSM_XToYHTo6B_MX-1200_MY-900_TuneCP5_13TeV-madgraph-pythia8.root")

tree1.spherical_region(), tree2.spherical_region(), tree3.spherical_region(), tree4.spherical_region(), tree5.spherical_region()
# Out:
# ntuple: /eos/uscms/store/user/srosenzw/sixb/ntuples/Summer2018UL/maxbtag/Official_NMSSM/NMSSM_XToYHTo6B_MX-450_MY-300_TuneCP5_13TeV-madgraph-pythia8/ntuple.root
# model: /eos/uscms/store/user/srosenzw/weaver/models/exp_sixb_official/feynnet_ranker_6b/20230731_7d266883bbfb88fe4e226783a7d1c9db_ranger_lr0.0047_batch2000_withbkg/predict_output/2018/maxbtag/NMSSM_XToYHTo6B_MX-450_MY-300_TuneCP5_13TeV-madgraph-pythia8.root
# ntuple: /eos/uscms/store/user/srosenzw/sixb/ntuples/Summer2018UL/maxbtag/Official_NMSSM/NMSSM_XToYHTo6B_MX-700_MY-400_TuneCP5_13TeV-madgraph-pythia8/ntuple.root
# model: /eos/uscms/store/user/srosenzw/weaver/models/exp_sixb_official/feynnet_ranker_6b/20230731_7d266883bbfb88fe4e226783a7d1c9db_ranger_lr0.0047_batch2000_withbkg/predict_output/2018/maxbtag/NMSSM_XToYHTo6B_MX-700_MY-400_TuneCP5_13TeV-madgraph-pythia8.root
# ...

# %%
mHX = np.concatenate((tree1.HX.m, tree2.HX.m, tree3.HX.m, tree4.HX.m, tree5.HX.m))
mH1 = np.concatenate((tree1.H1.m, tree2.H1.m, tree3.H1.m, tree4.H1.m, tree5.H1.m))
mH2 = np.concatenate((tree1.H2.m, tree2.H2.m, tree3.H2.m, tree4.H2.m, tree5.H2.m))

mX = np.concatenate((tree1.X.m, tree2.X.m, tree3.X.m, tree4.X.m, tree5.X.m))

# %%
test1 = np.concatenate((tree1.HX.m[tree1.resolved_mask & tree1.asr_hs_mask], tree2.HX.m[tree2.resolved_mask & tree2.asr_hs_mask], tree3.HX.m[tree3.resolved_mask & tree3.asr_hs_mask], tree4.HX.m[tree4.resolved_mask & tree4.asr_hs_mask], tree5.HX.m[tree5.resolved_mask & tree5.asr_hs_mask]))
test2 = np.concatenate((tree1.H1.m[tree1.resolved_mask & tree1.asr_hs_mask], tree2.H1.m[tree2.resolved_mask & tree2.asr_hs_mask], tree3.H1.m[tree3.resolved_mask & tree3.asr_hs_mask], tree4.H1.m[tree4.resolved_mask & tree4.asr_hs_mask], tree5.H1.m[tree5.resolved_mask & tree5.asr_hs_mask]))
test3 = np.concatenate((tree1.H2.m[tree1.resolved_mask & tree1.asr_hs_mask], tree2.H2.m[tree2.resolved_mask & tree2.asr_hs_mask], tree3.H2.m[tree3.resolved_mask & tree3.asr_hs_mask], tree4.H2.m[tree4.resolved_mask & tree4.asr_hs_mask], tree5.H2.m[tree5.resolved_mask & tree5.asr_hs_mask]))

test4 = np.concatenate((tree1.HX.m[~tree1.resolved_mask & tree1.asr_hs_mask], tree2.HX.m[~tree2.resolved_mask & tree2.asr_hs_mask], tree3.HX.m[~tree3.resolved_mask & tree3.asr_hs_mask], tree4.HX.m[~tree4.resolved_mask & tree4.asr_hs_mask], tree5.HX.m[~tree5.resolved_mask & tree5.asr_hs_mask]))
test5 = np.concatenate((tree1.H1.m[~tree1.resolved_mask & tree1.asr_hs_mask], tree2.H1.m[~tree2.resolved_mask & tree2.asr_hs_mask], tree3.H1.m[~tree3.resolved_mask & tree3.asr_hs_mask], tree4.H1.m[~tree4.resolved_mask & tree4.asr_hs_mask], tree5.H1.m[~tree5.resolved_mask & tree5.asr_hs_mask]))
test6 = np.concatenate((tree1.H2.m[~tree1.resolved_mask & tree1.asr_hs_mask], tree2.H2.m[~tree2.resolved_mask & tree2.asr_hs_mask], tree3.H2.m[~tree3.resolved_mask & tree3.asr_hs_mask], tree4.H2.m[~tree4.resolved_mask & tree4.asr_hs_mask], tree5.H2.m[~tree5.resolved_mask & tree5.asr_hs_mask]))

# %%
bkg = Bkg(get_qcd_ttbar('maxbtag'), floc=mloc)
# Out:
# /eos/uscms/store/user/srosenzw/sixb/ntuples
# Summer2018UL/maxbtag/QCD/QCD_bEnriched_HT100to200_TuneCP5_13TeV-madgraph-pythia8/ntuple.root
# Summer2018UL/maxbtag/QCD/QCD_bEnriched_HT200to300_TuneCP5_13TeV-madgraph-pythia8/ntuple.root
# Summer2018UL/maxbtag/QCD/QCD_bEnriched_HT300to500_TuneCP5_13TeV-madgraph-pythia8/ntuple.root
# Summer2018UL/maxbtag/QCD/QCD_bEnriched_HT500to700_TuneCP5_13TeV-madgraph-pythia8/ntuple.root
# Summer2018UL/maxbtag/QCD/QCD_bEnriched_HT700to1000_TuneCP5_13TeV-madgraph-pythia8/ntuple.root
# Summer2018UL/maxbtag/QCD/QCD_bEnriched_HT1000to1500_TuneCP5_13TeV-madgraph-pythia8/ntuple.root
# Summer2018UL/maxbtag/QCD/QCD_bEnriched_HT1500to2000_TuneCP5_13TeV-madgraph-pythia8/ntuple.root
# Summer2018UL/maxbtag/QCD/QCD_bEnriched_HT2000toInf_TuneCP5_13TeV-madgraph-pythia8/ntuple.root
# Summer2018UL/maxbtag/QCD/QCD_HT100to200_BGenFilter_TuneCP5_13TeV-madgraph-pythia8/ntuple.root
# ...

# %%
bkg.spherical_region()
# Out:
# REGION: concentric

# %%
bins = np.linspace(0,300,61)
fig, axs = plt.subplots(1, 3, figsize=(25, 7))

# sig_nX = Hist(mHX, bins=bins, density=True, ax=axs[0], label=r'$X\rightarrow Y(HH)H \rightarrow 6b$')
sig_nXr = Hist(test1, bins=bins, density=True, ax=axs[0], label=r'$X\rightarrow Y(HH)H \rightarrow 6b$')
bkg_nX = Hist(bkg.HX.m[bkg.asr_hs_mask], bins=bins, density=True, ax=axs[0], label='QCD + ttbar')
axs[0].set_xlabel(r"$H_X$ mass [GeV]")

# sig_n1 = Hist(mH1, bins=bins, density=True, ax=axs[1], label=r'$X\rightarrow Y(HH)H \rightarrow 6b$')
sig_n1r = Hist(test2, bins=bins, density=True, ax=axs[1], label=r'$X\rightarrow Y(HH)H \rightarrow 6b$')
bkg_n1 = Hist(bkg.H1.m[bkg.asr_hs_mask], bins=bins, density=True, ax=axs[1], label='QCD + ttbar')
axs[1].set_xlabel(r"$H_1$ mass [GeV]")

# sig_n2 = Hist(mH2, bins=bins, density=True, ax=axs[2], label=r'$X\rightarrow Y(HH)H \rightarrow 6b$')
sig_n2r = Hist(test3, bins=bins, density=True, ax=axs[2], label=r'$X\rightarrow Y(HH)H \rightarrow 6b$')
bkg_n2 = Hist(bkg.H2.m[bkg.asr_hs_mask], bins=bins, density=True, ax=axs[2], label='QCD + ttbar')
axs[2].set_xlabel(r"$H_2$ mass [GeV]")

for ax in axs:
    ax.legend(loc=1)
    ax.set_ylabel("AU")

fig.savefig("plots/feynnet/20230731_7d266883bbfb88fe4e226783a7d1c9db_ranger_lr0.0047_batch2000_withbkg/mh_sig_bkg_truthmatched_sr.pdf", bbox_inches='tight')

# %%
bins = np.linspace(0,300,61)
fig, axs = plt.subplots(1, 3, figsize=(25, 7))

# sig_nX = Hist(mHX, bins=bins, density=True, ax=axs[0], label=r'$X\rightarrow Y(HH)H \rightarrow 6b$')
sig_nXr = Hist(test4, bins=bins, density=True, ax=axs[0], label=r'$X\rightarrow Y(HH)H \rightarrow 6b$')
bkg_nX = Hist(bkg.HX.m, bins=bins, density=True, ax=axs[0], label='QCD + ttbar')
axs[0].set_xlabel(r"$H_X$ mass [GeV]")

# sig_n1 = Hist(mH1, bins=bins, density=True, ax=axs[1], label=r'$X\rightarrow Y(HH)H \rightarrow 6b$')
sig_n1r = Hist(test5, bins=bins, density=True, ax=axs[1], label=r'$X\rightarrow Y(HH)H \rightarrow 6b$')
bkg_n1 = Hist(bkg.H1.m, bins=bins, density=True, ax=axs[1], label='QCD + ttbar')
axs[1].set_xlabel(r"$H_1$ mass [GeV]")

# sig_n2 = Hist(mH2, bins=bins, density=True, ax=axs[2], label=r'$X\rightarrow Y(HH)H \rightarrow 6b$')
sig_n2r = Hist(test6, bins=bins, density=True, ax=axs[2], label=r'$X\rightarrow Y(HH)H \rightarrow 6b$')
bkg_n2 = Hist(bkg.H2.m, bins=bins, density=True, ax=axs[2], label='QCD + ttbar')
axs[2].set_xlabel(r"$H_2$ mass [GeV]")

for ax in axs:
    ax.legend(loc=1)
    ax.set_ylabel("AU")

fig.savefig("plots/feynnet/20230731_7d266883bbfb88fe4e226783a7d1c9db_ranger_lr0.0047_batch2000_withbkg/mh_sig_bkg_nontruthmatched_sr.pdf", bbox_inches='tight')

# %%
bins = np.linspace(375,1500,31)
fig, ax = plt.subplots()

sig_nX = Hist(mX, bins=bins, density=True, ax=ax, label=r'$X\rightarrow Y(HH)H \rightarrow 6b$')
bkg_nX = Hist(bkg.X.m, bins=bins, density=True, ax=ax, label='QCD + ttbar')
