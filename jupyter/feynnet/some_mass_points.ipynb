# %%
year = 'Summer2016UL'

# %%
from utils.analysis.gnn import model_path
if model_path[-1] == '/': model_path = model_path[:-1]
model_dir = model_path.split('/')[-2]

model_savein = f'plots/feynnet/{model_dir}'
if not os.path.exists(model_savein): os.makedirs(model_savein)
model_savein = f'plots/feynnet/{model_dir}/{year}'
if not os.path.exists(model_savein): os.makedirs(model_savein)
model_dir, model_savein
# Out:
# ('20230731_7d266883bbfb88fe4e226783a7d1c9db_ranger_lr0.0047_batch2000_withbkg',
#  'plots/feynnet/20230731_7d266883bbfb88fe4e226783a7d1c9db_ranger_lr0.0047_batch2000_withbkg/Summer2016UL')

# %%
mass_points = [
    [450,300],
    [700,400],
    [900,300],
    [900,600],
    [1000,400],
    [1000,700]
]

# %%
base = f'/eos/uscms/store/user/srosenzw/sixb/ntuples/{year}/maxbtag_4b/Official_NMSSM'
cmd = f"ls {base}"
output = subprocess.check_output(shlex.split(cmd))
output = output.decode('UTF-8')
output = output.split('\n')
output = [f"{base}/{out}/ntuple.root" for out in output if out.startswith('NMSSM')]
output = [out for out in output if [int(out.split("_")[4].split('-')[1]),int(out.split("_")[5].split('-')[1])] in mass_points]

# %%
# tree1 = SixB('/eos/uscms/store/user/srosenzw/sixb/ntuples/Summer2018UL/maxbtag_4b/Official_NMSSM/NMSSM_XToYHTo6B_MX-500_MY-300_TuneCP5_13TeV-madgraph-pythia8/ntuple.root')
# tree2 = SixB('/eos/uscms/store/user/srosenzw/sixb/ntuples/Summer2018UL/maxbtag_4b/Official_NMSSM/NMSSM_XToYHTo6B_MX-450_MY-250_TuneCP5_13TeV-madgraph-pythia8/ntuple.root')

# %%
signal = [SixB(out) for out in output]
# Out:
# /eos/uscms/store/user/srosenzw/weaver/models/exp_sixb_official/feynnet_ranker_6b/20230731_7d266883bbfb88fe4e226783a7d1c9db_ranger_lr0.0047_batch2000_withbkg/predict_output/2016postVFP
# [17:38:37] Loading model:                                                                             ]8;id=697291;file:///uscms_data/d3/srosenzw/workarea/higgs/sixb_analysis/CMSSW_10_6_19_patch2/src/sixb/utils/analysis/signal.py\signal.py]8;;\:]8;id=156653;file:///uscms_data/d3/srosenzw/workarea/higgs/sixb_analysis/CMSSW_10_6_19_patch2/src/sixb/utils/analysis/signal.py#119\119]8;;\
#            /eos/uscms/store/user/srosenzw/weaver/models/exp_sixb_official/feynnet_ranker_6b/20230731_
#            7d266883bbfb88fe4e226783a7d1c9db_ranger_lr0.0047_batch2000_withbkg/predict_output/2016post
#            VFP/NMSSM_XToYHTo6B_MX-1000_MY-400_TuneCP5_13TeV-madgraph-pythia8.root
# ...

# %%
[sig.spherical_region() for sig in signal]
# Out:
# REGION: concentric
# REGION: concentric
# REGION: concentric
# REGION: concentric
# REGION: concentric
# REGION: concentric
# [None, None, None, None, None, None]

# %% [markdown]
# Before background estimation

# %%
mx_bins = np.linspace(375,1500,31)
my_bins = np.linspace(150,900,31)
mh_bins = np.linspace(0,200,31)

# %%
signal[2].sample, ak.sum(signal[2].resolved_mask)
# Out:
# ('$M_X=$ 450 GeV, $M_Y=$ 300 GeV', 10918)

# %%
fig, axs = plt.subplots(figsize=(35,35), nrows=6, ncols=5)

for i,sig in enumerate(signal):
    sig.hist(sig.X.m, bins=mx_bins, ax=axs[i,0])
    sig.hist(sig.Y.m, bins=my_bins, ax=axs[i,1])
    sig.hist(sig.HX.m, bins=mh_bins, ax=axs[i,2])
    sig.hist(sig.H1.m, bins=mh_bins, ax=axs[i,3])
    sig.hist(sig.H2.m, bins=mh_bins, ax=axs[i,4])

    axs[i,0].set_xlabel(r'$M_X$ [GeV]')
    axs[i,1].set_xlabel(r'$M_Y$ [GeV]')
    axs[i,2].set_xlabel(r'$M_{HX}$ [GeV]')
    axs[i,3].set_xlabel(r'$M_{H1}$ [GeV]')
    axs[i,4].set_xlabel(r'$M_{H2}$ [GeV]')

# for ax in axs.flatten():
#     ax.set_xlabel(r'$M_X$ [GeV]')

plt.tight_layout()
fig.savefig(f'{model_savein}/some_mass_dists.pdf')

# %%
fig, axs = plt.subplots(figsize=(35,35), nrows=6, ncols=5)

for i,sig in enumerate(signal):
    sig.hist(sig.X.m[sig.asr_mask], bins=mx_bins, ax=axs[i,0])
    sig.hist(sig.Y.m[sig.asr_mask], bins=my_bins, ax=axs[i,1])
    sig.hist(sig.HX.m[sig.asr_mask], bins=mh_bins, ax=axs[i,2])
    sig.hist(sig.H1.m[sig.asr_mask], bins=mh_bins, ax=axs[i,3])
    sig.hist(sig.H2.m[sig.asr_mask], bins=mh_bins, ax=axs[i,4])

    axs[i,0].set_xlabel(r'Signal Region $M_X$ [GeV]')
    axs[i,1].set_xlabel(r'Signal Region $M_Y$ [GeV]')
    axs[i,2].set_xlabel(r'Signal Region $M_{HX}$ [GeV]')
    axs[i,3].set_xlabel(r'Signal Region $M_{H1}$ [GeV]')
    axs[i,4].set_xlabel(r'Signal Region $M_{H2}$ [GeV]')

# for ax in axs.flatten():
#     ax.set_xlabel(r'$M_X$ [GeV]')

plt.tight_layout()
fig.savefig(f'{model_savein}/some_mass_dists_sr.pdf')
