# %%
import uproot as up

# %%
tree = up.open("/eos/uscms/store/user/srosenzw/sixb/ntuples/2018_gnn_training/MX_450_550_700_900_1000_MY_300_300_400_300_600/signal.root:sixBtree")

# %%
fig, ax = plt.subplots()

_ = Hist(tree['X_m'].array(), bins=np.linspace(0,1200,100), ax=ax)
