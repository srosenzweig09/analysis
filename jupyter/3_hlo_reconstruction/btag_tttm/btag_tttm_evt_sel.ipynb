# %%
tree = Signal('/eos/uscms/store/user/srosenzw/sixb/ntuples/Summer2018UL/btag_tttm/NMSSM/NMSSM_XYH_YToHH_6b_MX_700_MY_400/ntuple.root')
# Out:
# /eos/uscms/store/user/srosenzw/sixb/ntuples/Summer2018UL/btag_pt/NMSSM/NMSSM_XYH_YToHH_6b_MX_700_MY_400/ntuple.root
# ---------------------------------------------------------------------------
# KeyInFileError                            Traceback (most recent call last)
# /uscms/home/srosenzw/nobackup/workarea/higgs/sixb_analysis/CMSSW_10_6_19_patch2/src/sixb/jupyter/3_hlo_reconstruction/btag_pt/evt_sel.ipynb Cell 1 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell://ssh-remote%2Bsrosenzw@cmslpcgpu1.fnal.gov/uscms/home/srosenzw/nobackup/workarea/higgs/sixb_analysis/CMSSW_10_6_19_patch2/src/sixb/jupyter/3_hlo_reconstruction/btag_pt/evt_sel.ipynb#W0sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> tree = Signal('/eos/uscms/store/user/srosenzw/sixb/ntuples/Summer2018UL/btag_pt/NMSSM/NMSSM_XYH_YToHH_6b_MX_700_MY_400/ntuple.root')
#
# File /uscms_data/d3/srosenzw/workarea/higgs/sixb_analysis/CMSSW_10_6_19_patch2/src/sixb/utils/analysis/signal.py:77, in Signal.__init__(self, filename, treename, year, presel, gen, b_cutflow)
#      75    print(filename)
#      76    self.filename = re.search('NMSSM_.+/', filename).group()[:-1]
# ---> 77 tree = uproot.open(f"{filename}:{treename}")
#      78 self.tree = tree
#      80 # Search for any keys beginning with an 'H' and followed somewhere by a '_'
#
# File /uscms_data/d3/srosenzw/mambaforge/envs/sixb/lib/python3.9/site-packages/uproot/reading.py:154, in open(path, object_cache, array_cache, custom_classes, decompression_executor, interpretation_executor, **options)
#     152     return file.root_directory
#     153 else:
# --> 154     return file.root_directory[object_path]
#
# File /uscms_data/d3/srosenzw/mambaforge/envs/sixb/lib/python3.9/site-packages/uproot/reading.py:2106, in ReadOnlyDirectory.__getitem__(self, where)
#    2103     return step
#    2105 else:
# -> 2106     return self.key(where).get()
#
# File /uscms_data/d3/srosenzw/mambaforge/envs/sixb/lib/python3.9/site-packages/uproot/reading.py:2056, in ReadOnlyDirectory.key(self, where)
#    2054     return last
#    2055 elif cycle is None:
# -> 2056     raise uproot.KeyInFileError(
#    2057         item, cycle="any", keys=self.keys(), file_path=self._file.file_path
#    2058     )
#    2059 else:
#    2060     raise uproot.KeyInFileError(
#    2061         item, cycle=cycle, keys=self.keys(), file_path=self._file.file_path
#    2062     )
#
# KeyInFileError: not found: 'sixBtree' (with any cycle number)
#
#     Available keys: (none!)
#
# in file /eos/uscms/store/user/srosenzw/sixb/ntuples/Summer2018UL/btag_pt/NMSSM/NMSSM_XYH_YToHH_6b_MX_700_MY_400/ntuple.root

# %%
ak.sum(tree.HX_pt > tree.H1_pt) / len(tree.HX_pt)
# Out:
# 0.7330985459023832

# %%
ak.sum(tree.HX_b1_genHflag == 0) / len(tree.HX_b1_genHflag)
# Out:
# 0.31177754251020895

# %%
# HX_found = (tree.HX_b1_genHflag == 0) & (tree.HX_b2_genHflag == 0)
# H1_found = (tree.H1_b1_genHflag == 1) & (tree.H1_b2_genHflag == 1)
# H2_found = (tree.H2_b1_genHflag == 2) & (tree.H2_b2_genHflag == 2)

H_b_genHflags = np.column_stack((tree.np('HX_b1_genHflag'), tree.np('HX_b2_genHflag'), tree.np('H1_b1_genHflag'), tree.np('H1_b2_genHflag'), tree.np('H2_b1_genHflag'), tree.np('H2_b2_genHflag')))

# %%
found_HX_select = (H_b_genHflags == 0).sum(axis=1) == 2
found_H1_select = (H_b_genHflags == 1).sum(axis=1) == 2
found_H2_select = (H_b_genHflags == 2).sum(axis=1) == 2

n_H_selected = np.sum(np.column_stack((found_HX_select, found_H1_select, found_H2_select)), axis=1)
n_H_selected.max()
# Out:
# 3

# %%
HX_found = (tree.HX_b1_genHflag == 0) & (tree.HX_b2_genHflag == 0)
H1_found = (tree.H1_b1_genHflag == 1) & (tree.H1_b2_genHflag == 1)
H2_found = (tree.H2_b1_genHflag == 2) & (tree.H2_b2_genHflag == 2)


n_h_paired = np.sum(np.column_stack((HX_found, H1_found, H2_found)), axis=1)
all_H_found = HX_found & H1_found & H2_found

n_h_paired
# Out:
# <Array [3, 0, 1, 0, 1, 0, ... 0, 0, 0, 0, 0, 0] type='46283 * int64'>

# %%
fig, ax = plt.subplots()

n1 = tree.hist(n_H_selected, bins=np.arange(5), ax=ax, label='Six Selected Jets')
n2 = tree.hist(n_h_paired, bins=np.arange(5), ax=ax, label='Reco H Candidates')
# n3 = tree.hist(n_h_paired[n_H_selected == 3], bins=np.arange(5), ax=ax)

# ax.set_ylim(0, 6000)

ax.set_xlabel('Number of True Higgs')

fig.savefig(f'plots/3_hlo_reconstruction/btag_pt/{tree.mxmy}_nH_1D.pdf')

n1/n1.sum(), n2/n2.sum()
# Out:
# (array([0.01207787, 0.19508243, 0.54168917, 0.25115053]),
#  array([0.70101333, 0.21975671, 0.03323034, 0.04599961]))

# %%
fig, ax = plt.subplots(figsize=(12,10))

n, ex, ey, im = Hist2d(n_H_selected, n_h_paired, bins=np.arange(5), ax=ax)

ax.set_xlabel('Number of True Higgs in Six Selected Jets')
ax.set_ylabel('Number of True Reco Higgs Candidates')

fig.colorbar(im, ax=ax)

ax.set_xticks(np.arange(5))
ax.set_yticks(np.arange(5))

ax.minorticks_off()

fig.savefig(f'plots/3_hlo_reconstruction/btag_pt/{tree.mxmy}_nH_2D.pdf')
