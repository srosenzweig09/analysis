# %%
MX_MY = [
   [450, 300],
   [500, 300],
   [600, 300],
   [600, 400],
   [700, 300],
   [700, 400],
   [700, 500],
   [800, 300],
   [800, 400],
   [800, 500],
   [800, 600],
   [900, 300],
   [900, 400],
   [900, 500],
   [900, 600],
   [900, 700],
   [1000, 300],
   [1000, 400],
   [1000, 500],
   [1000, 600],
   [1000, 700],
   [1000, 800],
   [1100, 300],
   [1100, 400],
   [1100, 500],
   [1100, 600],
   [1100, 700],
   [1100, 800],
   [1100, 900],
   [1200, 300],
   [1200, 400],
   [1200, 500],
   [1200, 600],
   [1200, 700],
   [1200, 800],
   [1200, 900],
]

# %%
MX_MY = np.array(MX_MY)

# %%
MX = MX_MY[:,0]
MY = MX_MY[:,1]

# %%
MX_min = 375 # GeV
MY_min = 250 # GeV

def f(MX):
   return MX - 125

# %%
fig, ax = plt.subplots()

ax.scatter(MX, MY, lw=5)
ax.set_xlabel(r'$M_X$ [GeV]')
ax.set_ylabel(r'$M_Y$ [GeV]')
ax.grid()

ax.plot([MX_min, MX.max()],[MY_min,f(MX.max())],c='gray',ls='--')

fig.savefig("plots/mass_grid.pdf", bbox_inches='tight')
plt.show()
