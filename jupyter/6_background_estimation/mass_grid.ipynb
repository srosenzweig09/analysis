# %%
mX = [450, 500, 600, 600, 700, 700, 700, 1000, 1000]
mY = [300, 300, 300, 400, 300, 400, 500,  300,  700]

# %%
fig, ax = plt.subplots()

ax.scatter(mX, mY, lw=10)
ax.set_xlabel(r'$M_X$ [GeV]')
ax.set_ylabel(r'$M_Y$ [GeV]')
ax.grid()

ax.plot([425,700],[300,575],c='gray',ls='--')

fig.savefig("mass_grid.pdf")
plt.show()
