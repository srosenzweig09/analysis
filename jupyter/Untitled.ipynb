# %%
import pickle as pk
import numpy as np

# %%
fn = "/uscms/home/srosenzw/nobackup/workarea/higgs/sixb_analysis/CMSSW_10_2_18/src/sixb/6jet_classifier/models/20210816_5btag_req/model/scaler_1.pkl"

# %%
obj = pk.load( open(fn,"rb") )

# %%
vars(obj)
# Out:
# {'feature_range': (0, 1),
#  'copy': True,
#  'clip': False,
#  'n_features_in_': 30,
#  'n_samples_seen_': 1331428,
#  'scale_': array([5.62511879e-04, 8.69483634e-04, 1.42853945e-03, 2.23558801e-03,
#         3.78722489e-03, 5.20537357e-03, 2.00039070e-01, 2.00039070e-01,
#         2.00039070e-01, 2.00039070e-01, 2.00039070e-01, 2.00039070e-01,
#         1.59155398e-01, 1.59155398e-01, 1.59155398e-01, 1.59155398e-01,
#         1.59155398e-01, 1.59155398e-01, 1.00171574e+00, 1.00160283e+00,
#         1.00176359e+00, 1.00172052e+00, 1.00161910e+00, 1.00168033e+00,
#         1.58093976e-04, 2.38094070e-04, 2.98570216e-04, 5.27123300e-04,
#         6.01913815e-04, 8.74812572e-04]),
#  'min_': array([-1.39122124e-02, -2.12886622e-02, -2.97572233e-02, -4.53207810e-02,
#         -7.58416258e-02, -1.04107581e-01,  5.00000000e-01,  5.00000000e-01,
#          5.00000000e-01,  5.00000000e-01,  5.00000000e-01,  5.00000000e-01,
# ...

# %%
input = np.array([ 120.153,  114.914,  75.994,  75.099,  61.896,  61.564, 
                  -0.525, -0.278, -0.992,  0.311, -1.057, -1.844, 
                  -1.140,  1.660,  0.878, 2.717,  3.042, -1.256,  
                  0.778,  0.700,  0.401,  0.996,  0.003, 0.996,  
                  108.143,  124.577,  80.956,  79.714,  67.812,  42.099])

# %%
input_scaled = np.array([0.05367528, 0.07862718, 0.0788032 , 0.12256964, 0.15857245,0.21635604, 
                         0.39497949, 0.44438914, 0.30156124, 0.56221215,0.2885587 , 0.13112795, 
                         0.31856285, 0.76419796, 0.63973844, 0.93242522, 0.98415072, 0.30010082, 
                         0.77810823, 0.70000821, 0.40043275, 0.99648224, 0.00187483, 0.99648238, 
                         0.01675363, 0.02943395, 0.02402065, 0.04192418, 0.04079353, 0.03670292])

# %%
input_scaled/input
# Out:
# array([ 4.46724426e-04,  6.84226291e-04,  1.03696608e-03,  1.63210748e-03,
#         2.56191757e-03,  3.51432720e-03, -7.52341886e-01, -1.59852209e+00,
#        -3.03993185e-01,  1.80775611e+00, -2.72997824e-01, -7.11106020e-02,
#        -2.79441096e-01,  4.60360217e-01,  7.28631481e-01,  3.43181899e-01,
#         3.23520947e-01, -2.38933774e-01,  1.00013911e+00,  1.00001173e+00,
#         9.98585411e-01,  1.00048418e+00,  6.24943333e-01,  1.00048432e+00,
#         1.54921077e-04,  2.36271142e-04,  2.96712412e-04,  5.25932459e-04,
#         6.01568012e-04,  8.71824034e-04])
