# %%
# %load_ext autoreload
# %autoreload 2

import os
import sys
import git

import uproot as ut
import awkward as ak
import numpy as np
import math
import vector
import sympy as sp

import re
from tqdm import tqdm
import timeit

sys.path.append( git.Repo('.', search_parent_directories=True).working_tree_dir )
from utils import *

# %%
tree = Tree(fc.sr.QCD_B_List)

# %%
sel = Selection(tree,mask=tree["b_6j_score"]>0.8,tag='b_6j_score>0.8')
sel2 = sel.masked(tree['b_3d_score']>0.99,tag='b_3d_score>0.99')

# %%
study.cutflow(tree,log=1)
study.cutflow(sel,log=1)
study.cutflow(sel2,log=1)

# %%
study.quick([sel,sel2],varlist=['b_6j_score','b_3d_score'],binlist=[np.linspace(0,1,30)]*2,s_colors=['r','b'])
