# %%
# %load_ext autoreload
# %autoreload 2

import os
import sys
import git

import uproot as ut
import awkward as ak
import numpy as np
import math
import vector
import sympy as sp

import re
from tqdm import tqdm
import timeit

sys.path.append( git.Repo('.', search_parent_directories=True).working_tree_dir )
from utils import *

# %%
signal_tree = Tree(fc.sr.NMSSM_MX_700_MY_400)
signal_selection = Selection(signal_tree)

# %%
study.cutflow([signal_tree],log=1,sumw2=0)

# %%
signal_study.njet(signal_selection)

# %%
signal_study.ijets(signal_selection,njets=7)
