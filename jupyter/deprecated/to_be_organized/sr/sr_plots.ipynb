# %%
# %load_ext autoreload
# %autoreload 2

import os
import sys
import git

import uproot as ut
import awkward as ak
import numpy as np
import math
import vector
import sympy as sp

import re
from tqdm import tqdm
import timeit

sys.path.append( git.Repo('.', search_parent_directories=True).working_tree_dir )
from utils import *

# %%
signal_tree = Tree( fc.sr.NMSSM_MX_700_MY_400 )
lumikey=2018

# %%
qcd_tree = Tree( fc.sr.QCD_B_List )

# %%
ttjets_tree = Tree(fc.sr.TTJets)

# %%
trees = [signal_tree,qcd_tree,ttjets_tree]

# %%
study.cutflow(trees,log=1,ratio=1,stacked=1,lumikey=lumikey,saveas="sr")

# %%
for tree in trees: print_raw_info(tree)
# Out:
# NMSSM & 0.3 & 1075746 & 454121 & 7565.69\\
# QCD\_bEnriched\_HT200to300 & 80430.0 & 18462184 & 9 & 2342.30\\
# QCD\_bEnriched\_HT300to500 & 16620.0 & 11197722 & 913 & 80953.82\\
# QCD\_bEnriched\_HT500to700 & 1487.0 & 9246898 & 5633 & 54115.28\\
# QCD\_bEnriched\_HT700to1000 & 296.5 & 1844165 & 2316 & 22244.81\\
# QCD\_bEnriched\_HT1000to1500 & 46.61 & 1330829 & 2903 & 6073.92\\
# QCD\_bEnriched\_HT1500to2000 & 3.72 & 1431254 & 4219 & 655.09\\
# QCD\_bEnriched\_HT2000toInf & 0.6462 & 401397 & 1240 & 119.26\\
# QCD\_HT200to300\_BGenFilter & 111700.0 & 18762564 & 1 & 355.65\\
# QCD\_HT300to500\_BGenFilter & 27960.0 & 17127050 & 213 & 20773.01\\
# QCD\_HT500to700\_BGenFilter & 3078.0 & 8292039 & 1008 & 22352.86\\
# QCD\_HT700to1000\_BGenFilter & 721.8 & 5952088 & 1791 & 12975.03\\
# QCD\_HT1000to1500\_BGenFilter & 138.2 & 1953159 & 1001 & 4231.26\\
# QCD\_HT1500to2000\_BGenFilter & 13.61 & 511470 & 405 & 643.81\\
# QCD\_HT2000toInf\_BGenFilter & 2.92 & 287303 & 287 & 174.26\\
# ...

# %%
print_bovers(trees)
# Out:
# Bkg/Signal: 38.42
# === File Info ===
# File: ['/eos/uscms/store/user/ekoenig/6BAnalysis/NTuples/2018/SR/NMSSM/NMSSM_XYH_YToHH_6b_MX_700_MY_400/ntuple.root']
# Total Events:    [1075746.0]
# Raw Events:      [454121]
# Selected Events: 454121
# === File Info ===
# ...

# %%
info = dict(log=1,ratio=1,stacked=True,flip=True,lumikey=lumikey,saveas="sr")
study.njets(trees,**info)

# %%
info = dict(log=1,ratio=1,stacked=True,flip=True,lumikey=lumikey,saveas="sr")
study.ijets(trees,njets=6,**info)

# %%
info = dict(log=1,ratio=1,stacked=True,flip=True,lumikey=lumikey,saveas="sr")
study.ihiggs(trees,njets=6,**info)
