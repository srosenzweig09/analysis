# %%
inner = 25
outer = 40
v_center = 125 + (inner + outer) / np.sqrt(2)

# %%
fontsize = 25

acr = plt.Circle((125, 125), outer, color='#e67db8', alpha=0.5)
acr_ring = plt.Circle((125, 125), outer, ec='k', fill=False)
asr_block = plt.Circle((125, 125), inner, color='white')
asr = plt.Circle((125, 125), inner, color='#70a9cb', alpha=0.75)
asr_ring = plt.Circle((125, 125), inner, ec='k', fill=False)

vcr = plt.Circle((v_center, v_center), outer, color='#ffa95e', alpha=0.5)
vcr_ring = plt.Circle((v_center, v_center), outer, ec='k', fill=False)
vsr_block = plt.Circle((v_center, v_center), inner, color='white')
vsr = plt.Circle((v_center, v_center), inner, color='#249633', alpha=0.5)
vsr_ring = plt.Circle((v_center, v_center), inner, ec='k', fill=False)

fig, ax = plt.subplots()

ax.add_patch(acr)
ax.add_patch(acr_ring)
ax.add_patch(asr_block)
ax.add_patch(asr)
ax.add_patch(asr_ring)

ax.text(125,125,r'$A_{SR}$', ha='center', va='center', fontsize=fontsize)
ax.text(98,152,r'$A_{CR}$', ha='left', va='top', fontsize=fontsize)#, font_dict=font_dict)
ax.text(v_center,v_center,r'$V_{SR}$', ha='center', va='center', fontsize=fontsize)
ax.text(145,199,r'$V_{CR}$', ha='left', va='top', fontsize=fontsize)#, font_dict=font_dict)

ax.add_patch(vcr)
ax.add_patch(vcr_ring)
ax.add_patch(vsr_block)
ax.add_patch(vsr)
ax.add_patch(vsr_ring)

ax.set_xlim(75,220)
ax.set_ylim(75,220)

ax.set_xlabel(r'$M(H_1)$ GeV')
ax.set_ylabel(r'$M(H_2)$ GeV')

fig.savefig('plots/6_background_modeling/mass_regions.pdf')
