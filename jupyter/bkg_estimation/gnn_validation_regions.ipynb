# %%
gnn_data = data_from_gnn('/eos/uscms/store/user/srosenzw/sixb/ntuples/Summer2018UL/maxbtag_4b/JetHT_Data_UL/ntuple.root')
# Out:
# /eos/uscms/store/user/srosenzw/sixb/ntuples/Summer2018UL/maxbtag_4b/JetHT_Data_UL/ntuple.root
# /uscms/home/srosenzw/nobackup/workarea/higgs/sixb_analysis/CMSSW_10_6_19_patch2/src/sixb/weaver-multiH/weaver/models/exp_xy/XY_3H_reco_ranker/20230315_ranger_lr0.0047_batch1024__MX_450_550_700_900_1000_sigma_25_bkg_loss_1_withbkg/predict_output/JetHT_Data_UL.root_4b.awkd

# %%
gnn_data.spherical_region()
# Out:
# multiple
# This should print?

# %%
gnn_data.multi_region()

# %%
gnn_data.train()
# Out:
# 0.65
# .. training in validation region
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /uscms/home/srosenzw/nobackup/workarea/higgs/sixb_analysis/CMSSW_10_6_19_patch2/src/sixb/jupyter/5_background_estimation/gnn_validation_regions.ipynb Cell 3 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell://ssh-remote%2Bsrosenzw@cmslpcgpu2.fnal.gov/uscms/home/srosenzw/nobackup/workarea/higgs/sixb_analysis/CMSSW_10_6_19_patch2/src/sixb/jupyter/5_background_estimation/gnn_validation_regions.ipynb#X10sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> gnn_data.train()
#
# File /uscms_data/d3/srosenzw/workarea/higgs/sixb_analysis/CMSSW_10_6_19_patch2/src/sixb/utils/analysis/signal.py:911, in Data.train(self)
#     909 print(self.score_cut)
#     910 print(".. training in validation region")
# --> 911 self.train_vr()
#     912 print()
#     913 print(".. training in analysis region")
#
# ...

# %%
ak.sum(gnn_data.vcr_ls_mask)
# Out:
# 34305

# %%
from matplotlib.patches import Circle

# %%
gnn_data.val_center_1, gnn_data.val_center_2, gnn_data.val_center_3, gnn_data.val_center_4
# Out:
# ((178.03300858899107, 178.03300858899107, 178.03300858899107),
#  (178.03300858899107, 178.03300858899107, 71.96699141100893),
#  (178.03300858899107, 71.96699141100893, 178.03300858899107),
#  (71.96699141100893, 178.03300858899107, 178.03300858899107))

# %%
fig, ax = plt.subplots()

ax.set_xlim(0,250)
ax.set_ylim(0,250)

circle1 = Circle(gnn_data.val_center_1, radius=50, color='blue', fill=False, lw=2)
circle2 = Circle(gnn_data.val_center_2, radius=50, color='blue', fill=False, lw=2)
circle3 = Circle(gnn_data.val_center_3, radius=50, color='blue', fill=False, lw=2)
circle4 = Circle(gnn_data.val_center_4, radius=50, color='blue', fill=False, lw=2)
circle5 = Circle(gnn_data.val_center_1, radius=25, color='blue', fill=False, lw=2)
circle6 = Circle(gnn_data.val_center_2, radius=25, color='blue', fill=False, lw=2)
circle7 = Circle(gnn_data.val_center_3, radius=25, color='blue', fill=False, lw=2)
circle8 = Circle(gnn_data.val_center_4, radius=25, color='blue', fill=False, lw=2)
circle_acr = Circle((125,125), radius=50, color='green', fill=False, lw=2)
circle_asr = Circle((125,125), radius=25, color='green', fill=False, lw=2)

ax.add_artist(circle_acr)
ax.add_artist(circle_asr)
ax.add_artist(circle1)
ax.add_artist(circle2)
ax.add_artist(circle3)
ax.add_artist(circle4)
ax.add_artist(circle5)
ax.add_artist(circle6)
ax.add_artist(circle7)
ax.add_artist(circle8)
