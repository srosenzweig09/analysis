# %%
tree = Signal(get_presel(), presel=True)
tree.cutflow, tree.nevents
# Out:
# /eos/uscms/store/user/srosenzw/sixb/ntuples/Summer2018UL/NMSSM_presel/NMSSM_XYH_YToHH_6b_MX_700_MY_400/ntuple.root
# (array([17922.   , 12611.448, 10188.794], dtype=float32), 55998)

# %%
get_presel()
# Out:
# '/eos/uscms/store/user/srosenzw/sixb/ntuples/Summer2018UL/NMSSM_presel/NMSSM_XYH_YToHH_6b_MX_700_MY_400/ntuple.root'

# %%
tree = Signal('/eos/uscms/store/user/srosenzw/sixb/ntuples/Summer2018UL/NMSSM_gen/NMSSM_XYH_YToHH_6b_MX_700_MY_400/ntuple.root')
# Out:
# /eos/uscms/store/user/srosenzw/sixb/ntuples/Summer2018UL/NMSSM_gen/NMSSM_XYH_YToHH_6b_MX_700_MY_400/ntuple.root
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File /uscms_data/d3/srosenzw/mambaforge/envs/sixb/lib/python3.9/site-packages/uproot/source/file.py:112, in MemmapSource._open(self)
#     111 try:
# --> 112     self._file = numpy.memmap(self._file_path, dtype=self._dtype, mode="r")
#     113     self._fallback = None
#
# File /uscms_data/d3/srosenzw/mambaforge/envs/sixb/lib/python3.9/site-packages/numpy/core/memmap.py:228, in memmap.__new__(subtype, filename, dtype, mode, offset, shape, order)
#     227 else:
# --> 228     f_ctx = open(os_fspath(filename), ('r' if mode == 'c' else mode)+'b')
#     230 with f_ctx as fid:
#
# ...

# %%
tree.keys()
# Out:
# ['Run',
#  'LumiSec',
#  'Event',
#  'n_other_pv',
#  'rhofastjet_all',
#  'n_mu_loose',
#  'n_ele_loose',
#  'mu_1_m',
#  'mu_1_pt',
#  'mu_1_eta',
#  'mu_1_phi',
#  'mu_2_m',
#  'mu_2_pt',
#  'mu_2_eta',
#  'mu_2_phi',
#  'ele_1_m',
#  'ele_1_pt',
#  'ele_1_eta',
#  'ele_1_phi',
#  'ele_2_m',
#  'ele_2_pt',
#  'ele_2_eta',
#  'ele_2_phi',
#  'n_total_jet',
#  'n_jet',
#  'jet_E',
#  'jet_m',
#  'jet_mRegressed',
#  'jet_pt',
#  'jet_ptRegressed',
#  'jet_eta',
#  'jet_phi',
#  'jet_signalId',
#  'jet_higgsIdx',
#  'jet_genIdx',
#  'jet_btag',
#  'jet_qgl',
#  'jet_id',
#  'jet_puid',
#  'b_6j_score',
#  'n_pu',
#  'n_true_int',
#  'lhe_ht',
#  'btagSF_WP_M',
#  'n_genjet',
#  'genjet_E',
#  'genjet_m',
#  'genjet_pt',
#  'genjet_eta',
#  'genjet_phi',
#  'genjet_partonFlav',
#  'genjet_hadronFlav',
#  'genjet_signalId',
#  'genjet_recoIdx',
#  'genWeight',
#  'PUWeight',
#  'PUWeight_up',
#  'PUWeight_down',
#  'LHEPdfWeight',
#  'LHEPdfWeight_var0',
#  'LHEPdfWeight_var1',
# ...

# %%
tree = Signal(get_NMSSM(700,400))
# Out:
# /eos/uscms/store/user/srosenzw/sixb/ntuples/Summer2018UL/bias/NMSSM/NMSSM_XYH_YToHH_6b_MX_700_MY_400/ntuple.root

# %%
tree.keys()
# Out:
# ['Run',
#  'LumiSec',
#  'Event',
#  'n_other_pv',
#  'rhofastjet_all',
#  'gen_X_fc_m',
#  'gen_X_fc_pt',
#  'gen_X_fc_eta',
#  'gen_X_fc_phi',
#  'gen_X_m',
#  'gen_X_pt',
#  'gen_X_eta',
#  'gen_X_phi',
#  'gen_Y_m',
#  'gen_Y_pt',
#  'gen_Y_eta',
#  'gen_Y_phi',
#  'gen_HX_m',
#  'gen_HX_pt',
#  'gen_HX_eta',
#  'gen_HX_phi',
#  'gen_HY1_m',
#  'gen_HY1_pt',
#  'gen_HY1_eta',
#  'gen_HY1_phi',
#  'gen_HY2_m',
#  'gen_HY2_pt',
#  'gen_HY2_eta',
#  'gen_HY2_phi',
#  'gen_HX_b1_m',
#  'gen_HX_b1_pt',
#  'gen_HX_b1_eta',
#  'gen_HX_b1_phi',
#  'gen_HX_b2_m',
#  'gen_HX_b2_pt',
#  'gen_HX_b2_eta',
#  'gen_HX_b2_phi',
#  'gen_HY1_b1_m',
#  'gen_HY1_b1_pt',
#  'gen_HY1_b1_eta',
#  'gen_HY1_b1_phi',
#  'gen_HY1_b2_m',
#  'gen_HY1_b2_pt',
#  'gen_HY1_b2_eta',
#  'gen_HY1_b2_phi',
#  'gen_HY2_b1_m',
#  'gen_HY2_b1_pt',
#  'gen_HY2_b1_eta',
#  'gen_HY2_b1_phi',
#  'gen_HY2_b2_m',
#  'gen_HY2_b2_pt',
#  'gen_HY2_b2_eta',
#  'gen_HY2_b2_phi',
#  'gen_HX_b1_genjet_m',
# ...

# %%
avg_total_jet = np.around(np.average(tree.np('n_total_jet')),2)
avg_reco_jet  = np.around(np.average(tree.np('n_jet')),2)

avg_total_jet, avg_reco_jet
# Out:
# (10.17, 7.2)

# %%
bins_njet = np.arange(22)

fig, ax = plt.subplots()

ax.set_title(r"M$_\mathrm{X}$ = 700 GeV, M$_\mathrm{Y}$ = 400 GeV", fontsize=22, loc='right')
Hist(tree.n_total_jet, bins=bins_njet, ax=ax, label=f'Total ({avg_total_jet})')
Hist(tree.n_jet, bins=bins_njet, ax=ax, label=f'Presel ({avg_reco_jet})')
ax.set_xlabel("Number of Reco Jets in Event")
ax.set_ylabel("Events")
# ax.legend(fontsize='x-small')

# plt.savefig("plots/1_signal_exploration/jet_multiplicity.pdf")
# Out:
# Text(0, 1, 'Events')
