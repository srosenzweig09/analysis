# %% [markdown]
# ### Load the samples

# %%
from utils.analysis.feyn import model_name
model_savein = f'plots/feynnet/{model_name}'

# %%
sig = SixB(get_NMSSM(jets='btag_pt', private=True), feyn=False)
# Out:
# [11:17:54] Loading                                                 ]8;id=697065;file:///uscms_data/d3/srosenzw/workarea/higgs/sixb_analysis/CMSSW_10_6_19_patch2/src/sixb/utils/analysis/signal.py\signal.py]8;;\:]8;id=924239;file:///uscms_data/d3/srosenzw/workarea/higgs/sixb_analysis/CMSSW_10_6_19_patch2/src/sixb/utils/analysis/signal.py#100\100]8;;\
#            Summer2018UL/btag_pt/NMSSM/NMSSM_XYH_YToHH_6b_MX_700_MY
#            _400/ntuple.root...

# %%
noml_bkg = Bkg(get_qcd_ttbar('btag_pt'), feyn=False)
# Out:
# /eos/uscms/store/user/srosenzw/sixb/ntuples
# Summer2018UL/btag_pt/QCD/QCD_bEnriched_HT100to200_TuneCP5_13TeV-madgraph-pythia8/ntuple.root
# Summer2018UL/btag_pt/QCD/QCD_bEnriched_HT200to300_TuneCP5_13TeV-madgraph-pythia8/ntuple.root
# Summer2018UL/btag_pt/QCD/QCD_bEnriched_HT300to500_TuneCP5_13TeV-madgraph-pythia8/ntuple.root
# Summer2018UL/btag_pt/QCD/QCD_bEnriched_HT500to700_TuneCP5_13TeV-madgraph-pythia8/ntuple.root
# Summer2018UL/btag_pt/QCD/QCD_bEnriched_HT700to1000_TuneCP5_13TeV-madgraph-pythia8/ntuple.root
# Summer2018UL/btag_pt/QCD/QCD_bEnriched_HT1000to1500_TuneCP5_13TeV-madgraph-pythia8/ntuple.root
# Summer2018UL/btag_pt/QCD/QCD_bEnriched_HT1500to2000_TuneCP5_13TeV-madgraph-pythia8/ntuple.root
# Summer2018UL/btag_pt/QCD/QCD_bEnriched_HT2000toInf_TuneCP5_13TeV-madgraph-pythia8/ntuple.root
# Summer2018UL/btag_pt/QCD/QCD_HT100to200_BGenFilter_TuneCP5_13TeV-madgraph-pythia8/ntuple.root
# ...

# %%
bins = np.linspace(0,350,31)
labels = [r'$H_X$ Mass [GeV]', r'$H_1$ Mass [GeV]', r'$H_2$ Mass [GeV]']

# %%
fig, axs = plt.subplots(ncols=3, figsize=(20,7))

ax = axs[0]
noml_bkg.hist(noml_bkg.HX.m, bins=bins, ax=ax, density=True)
Hist(sig.HX.m, bins=bins, ax=ax, density=True, weights=sig.scale)
# Out:
# array([0.00000000e+00, 0.00000000e+00, 4.45199839e-05, 4.89719911e-04,
#        3.69516178e-03, 7.70187052e-03, 1.47808809e-02, 2.81148367e-02,
#        5.38478196e-02, 1.05590880e-01, 1.60593465e-01, 1.44314945e-01,
#        8.66591930e-02, 6.05344772e-02, 5.32293916e-02, 4.79819775e-02,
#        4.29412723e-02, 3.55399251e-02, 3.01389098e-02, 2.36266255e-02,
#        2.03815699e-02, 1.62029862e-02, 1.48472190e-02, 1.09353662e-02,
#        9.11277533e-03, 7.75700808e-03, 6.51234388e-03, 5.31208515e-03,
#        4.95648384e-03, 4.15629148e-03])

# %% [markdown]
# ### GNN-Related Distributions

# %%
import uproot
f = uproot.open("/eos/uscms/store/user/srosenzw/sixb/ntuples/Summer2018UL/maxbtag_4b/QCD/QCD_bEnriched_HT100to200_TuneCP5_13TeV-madgraph-pythia8/ntuple.root")
f.keys()
# Out:
# []

# %%
test = uproot.open("/eos/uscms/store/user/srosenzw/sixb/ntuples/Summer2018UL/maxbtag_4b/Official_NMSSM/syst/HF_2018/up/NMSSM_XToYHTo6B_MX-900_MY-700_TuneCP5_13TeV-madgraph-pythia8/ntuple.root")

# %%
# sig = SixB(get_NMSSM())
noml_bkg = Bkg(get_qcd_ttbar('maxbtag_4b'))
# Out:
# /eos/uscms/store/user/srosenzw/sixb/ntuples
# Summer2018UL/maxbtag_4b/QCD/QCD_bEnriched_HT100to200_TuneCP5_13TeV-madgraph-pythia8/ntuple.root
# [NO KEYS IN FILE] .. skipping Summer2018UL/maxbtag_4b/QCD/QCD_bEnriched_HT100to200_TuneCP5_13TeV-madgraph-pythia8/ntuple.root
# Summer2018UL/maxbtag_4b/QCD/QCD_bEnriched_HT200to300_TuneCP5_13TeV-madgraph-pythia8/ntuple.root
# Summer2018UL/maxbtag_4b/QCD/QCD_bEnriched_HT300to500_TuneCP5_13TeV-madgraph-pythia8/ntuple.root
# Summer2018UL/maxbtag_4b/QCD/QCD_bEnriched_HT500to700_TuneCP5_13TeV-madgraph-pythia8/ntuple.root
# Summer2018UL/maxbtag_4b/QCD/QCD_bEnriched_HT700to1000_TuneCP5_13TeV-madgraph-pythia8/ntuple.root
# Summer2018UL/maxbtag_4b/QCD/QCD_bEnriched_HT1000to1500_TuneCP5_13TeV-madgraph-pythia8/ntuple.root
# Summer2018UL/maxbtag_4b/QCD/QCD_bEnriched_HT1500to2000_TuneCP5_13TeV-madgraph-pythia8/ntuple.root
# Summer2018UL/maxbtag_4b/QCD/QCD_bEnriched_HT2000toInf_TuneCP5_13TeV-madgraph-pythia8/ntuple.root
# ...
