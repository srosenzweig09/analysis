# %%
import uproot
file = uproot.open("root://cmseos.fnal.gov//store/user/srosenzw/analysis/NMSSM_Luca/NMSSM_XYH_YToHH_6b_MX_700_MY_400/ntuple.root")

# %%
file.keys()
# Out:
# ['h_cutflow;1', 'sixBtree;1', 'NormWeightTree;1']

# %%
from utils.fileUtils.sr import NMSSM_MX_450_MY_300, NMSSM_MX_500_MY_300, NMSSM_MX_600_MY_300, NMSSM_MX_600_MY_400, NMSSM_MX_700_MY_300, NMSSM_MX_700_MY_400, NMSSM_MX_700_MY_500

# %%
datTree = Tree(JetHT_Data_UL)
datTree.initialize_t6_X()

X = datTree.t6_X

# %%
sigTree1 = Tree(NMSSM_MX_450_MY_300)
sigTree2 = Tree(NMSSM_MX_500_MY_300)
sigTree3 = Tree(NMSSM_MX_600_MY_300)
sigTree4 = Tree(NMSSM_MX_600_MY_400)
sigTree5 = Tree(NMSSM_MX_700_MY_300)
sigTree6 = Tree(NMSSM_MX_700_MY_400)
sigTree7 = Tree(NMSSM_MX_700_MY_500)

# %%
sigTree.initialize_t6_X()
sigTree1.initialize_t6_X()
sigTree2.initialize_t6_X()
sigTree4.initialize_t6_X()

# %%
### SIGNAL ###
# sig_6jNN_mask = sigTree.b_6j_score > cut_6jNN # pass 6jNN mask

sig1_Dm_cand = abs(sigTree1.t6_higgs_m - 125)

# mass veto
sig1_SR = ak.all(sig1_Dm_cand <= SR_edge, axis=1) # SR
sig1_VR = ak.all(sig1_Dm_cand > SR_edge, axis=1) & ak.all(sig1_Dm_cand <= VR_edge, axis=1) # VR
sig1_CR = ak.all(sig1_Dm_cand > VR_edge, axis=1) # CR
# Out:
# ---------------------------------------------------------------------------
#
# NameError                                 Traceback (most recent call last)
#
# /tmp/ipykernel_12215/494575371.py in <module>
#
#       2 # sig_6jNN_mask = sigTree.b_6j_score > cut_6jNN # pass 6jNN mask
#
#       3
#
# ----> 4 sig1_Dm_cand = abs(sigTree1.t6_higgs_m - 125)
#
#       5
#
#       6 # mass veto
#
#
#
# NameError: name 'sigTree1' is not defined

# %%
### SIGNAL ###
# sig_6jNN_mask = sigTree.b_6j_score > cut_6jNN # pass 6jNN mask

sig2_Dm_cand = abs(sigTree2.t6_higgs_m - 125)

# mass veto
sig2_SR = ak.all(sig2_Dm_cand <= SR_edge, axis=1) # SR
sig2_VR = ak.all(sig2_Dm_cand > SR_edge, axis=1) & ak.all(sig2_Dm_cand <= VR_edge, axis=1) # VR
sig2_CR = ak.all(sig2_Dm_cand > VR_edge, axis=1) # CR

# %%
### SIGNAL ###
# sig_6jNN_mask = sigTree.b_6j_score > cut_6jNN # pass 6jNN mask

sig4_Dm_cand = abs(sigTree4.t6_higgs_m - 125)

# mass veto
sig4_SR = ak.all(sig4_Dm_cand <= SR_edge, axis=1) # SR
sig4_VR = ak.all(sig4_Dm_cand > SR_edge, axis=1) & ak.all(sig4_Dm_cand <= VR_edge, axis=1) # VR
sig4_CR = ak.all(sig4_Dm_cand > VR_edge, axis=1) # CR
# Out:
# ---------------------------------------------------------------------------
#
# NameError                                 Traceback (most recent call last)
#
# /tmp/ipykernel_12215/2512449211.py in <module>
#
#       2 # sig_6jNN_mask = sigTree.b_6j_score > cut_6jNN # pass 6jNN mask
#
#       3
#
# ----> 4 sig4_Dm_cand = abs(sigTree4.t6_higgs_m - 125)
#
#       5
#
#       6 # mass veto
#
#
#
# NameError: name 'sigTree4' is not defined

# %%
print(int(ak.sum(sig1_SR)*sigTree1.scale))
print(int(ak.sum(sig1_VR)*sigTree1.scale))
print(int(ak.sum(sig1_CR)*sigTree1.scale))
# Out:
# ---------------------------------------------------------------------------
#
# NameError                                 Traceback (most recent call last)
#
# /tmp/ipykernel_12215/3926288368.py in <module>
#
# ----> 1 print(int(ak.sum(sig1_SR)*sigTree1.scale))
#
#       2 print(int(ak.sum(sig1_VR)*sigTree1.scale))
#
#       3 print(int(ak.sum(sig1_CR)*sigTree1.scale))
#
#
#
# NameError: name 'sig1_SR' is not defined

# %%
### SIGNAL ###
# score veto
sig1_ls_mask = ak.sum(sigTree1.t6_jet_btag, axis=1)/6 < opt_cut # ls
sig1_hs_mask = ak.sum(sigTree1.t6_jet_btag, axis=1)/6 >= opt_cut # hs

# combination
sig1_SRhs_mask = sig1_SR & sig1_hs_mask
sig1_SRls_mask = sig1_SR & sig1_ls_mask
sig1_VRhs_mask = sig1_VR & sig1_hs_mask
sig1_VRls_mask = sig1_VR & sig1_ls_mask
sig1_CRhs_mask = sig1_CR & sig1_hs_mask
sig1_CRls_mask = sig1_CR & sig1_ls_mask
# Out:
# ---------------------------------------------------------------------------
#
# NameError                                 Traceback (most recent call last)
#
# /tmp/ipykernel_12215/3845608628.py in <module>
#
#       1 ### SIGNAL ###
#
#       2 # score veto
#
# ----> 3 sig1_ls_mask = ak.sum(sigTree1.t6_jet_btag, axis=1)/6 < opt_cut # ls
#
#       4 sig1_hs_mask = ak.sum(sigTree1.t6_jet_btag, axis=1)/6 >= opt_cut # hs
#
#       5
#
#
#
# NameError: name 'sigTree1' is not defined

# %%
### SIGNAL ###
# score veto
sig2_ls_mask = ak.sum(sigTree2.t6_jet_btag, axis=1)/6 < opt_cut # ls
sig2_hs_mask = ak.sum(sigTree2.t6_jet_btag, axis=1)/6 >= opt_cut # hs

# combination
sig2_SRhs_mask = sig2_SR & sig2_hs_mask
sig2_SRls_mask = sig2_SR & sig2_ls_mask
sig2_VRhs_mask = sig2_VR & sig2_hs_mask
sig2_VRls_mask = sig2_VR & sig2_ls_mask
sig2_CRhs_mask = sig2_CR & sig2_hs_mask
sig2_CRls_mask = sig2_CR & sig2_ls_mask

# %%
### SIGNAL ###
# score veto
sig4_ls_mask = ak.sum(sigTree4.t6_jet_btag, axis=1)/6 < opt_cut # ls
sig4_hs_mask = ak.sum(sigTree4.t6_jet_btag, axis=1)/6 >= opt_cut # hs

# combination
sig4_SRhs_mask = sig4_SR & sig4_hs_mask
sig4_SRls_mask = sig4_SR & sig4_ls_mask
sig4_VRhs_mask = sig4_VR & sig4_hs_mask
sig4_VRls_mask = sig4_VR & sig4_ls_mask
sig4_CRhs_mask = sig4_CR & sig4_hs_mask
sig4_CRls_mask = sig4_CR & sig4_ls_mask

# %%
print(int(ak.sum(sig1_SRls_mask)*sigTree1.scale))
print(int(ak.sum(sig1_SRhs_mask)*sigTree1.scale))
print(int(ak.sum(sig1_VRls_mask)*sigTree1.scale))
print(int(ak.sum(sig1_VRhs_mask)*sigTree1.scale))
print(int(ak.sum(sig1_CRls_mask)*sigTree1.scale))
print(int(ak.sum(sig1_CRhs_mask)*sigTree1.scale))
# Out:
# ---------------------------------------------------------------------------
#
# NameError                                 Traceback (most recent call last)
#
# /tmp/ipykernel_27748/1590489776.py in <module>
#
# ----> 1 print(int(ak.sum(sig1_SRls_mask)*sigTree1.scale))
#
#       2 print(int(ak.sum(sig1_SRhs_mask)*sigTree1.scale))
#
#       3 print(int(ak.sum(sig1_VRls_mask)*sigTree1.scale))
#
#       4 print(int(ak.sum(sig1_VRhs_mask)*sigTree1.scale))
#
#       5 print(int(ak.sum(sig1_CRls_mask)*sigTree1.scale))
#
#
#
# NameError: name 'sig1_SRls_mask' is not defined

# %%
fig, ax = plt.subplots()

xmin = mX - 0.3*mX
xmax = mX + 0.15*mX
nbins = 100

# n_sig_SRhs, e = Hist(sig_X.m[sig_SRhs_mask], bins=np.linspace(0,max_mass,nbins), label='SR-hs', scale=sigTree.scale, ax=ax)
# S = n_sig_SRhs[(e[:-1]>xmin) & (e[:-1]<xmax)].sum()
# print("S =",S)

fig.suptitle("Signal Region")

ax.set_title(sigTree.sample, loc='right')

## How many signal jets found?
n_sig_SRhs, e = Hist(sig_X.m[sig_SRhs_mask], bins=mBins, label='700, 400', scale=sigTree.scale, ax=ax)
n_sig1_SRhs, e = Hist(sigTree1.t6_X.m[sig1_SRhs_mask], bins=mBins, label='450, 300', scale=sigTree1.scale, ax=ax)
n_sig2_SRhs, e = Hist(sigTree2.t6_X.m[sig2_SRhs_mask], bins=mBins, label='500, 300', scale=sigTree1.scale, ax=ax)
n_sig4_SRhs, e = Hist(sigTree4.t6_X.m[sig4_SRhs_mask], bins=mBins, label='600, 400', scale=sigTree1.scale, ax=ax)
# n, e = Hist(sig_X.m[sig_SRhs_mask & (ak.sum(sigTree.t6_jet_signalId > -1, axis=1) == 6)], bins=np.linspace(250,1250,nbins), label='6 jets found', scale=sigTree.scale, ax=ax)
# N = n.sum()
# n, e = Hist(sig_X.m[sig_SRhs_mask & (ak.sum(sigTree.t6_jet_signalId > -1, axis=1) == 5)], bins=np.linspace(250,1250,nbins), label='5 jets found', scale=sigTree.scale, ax=ax)
# N += n.sum()
# n, e = Hist(sig_X.m[sig_SRhs_mask & (ak.sum(sigTree.t6_jet_signalId > -1, axis=1) == 4)], bins=np.linspace(250,1250,nbins), label='4 jets found', scale=sigTree.scale, ax=ax)
N += n.sum()

print(n_sig_SRhs.sum())
print(N)
print(f"{(n_sig_SRhs.sum()-N)/n_sig_SRhs.sum()*100:.1f}%")

ax.set_xlabel(r'Six Jet $m_\mathrm{inv}$ [GeV]')
ax.set_ylabel('Events')

# fig.savefig(f'plots/{sigTree.mXmY}_v_dat_minv6.pdf')
# Out:
# ---------------------------------------------------------------------------
#
# NameError                                 Traceback (most recent call last)
#
# /tmp/ipykernel_2707/1438537799.py in <module>
#
#      15 ## How many signal jets found?
#
#      16 n_sig_SRhs, e = Hist(sig_X.m[sig_SRhs_mask], bins=mBins, label='700, 400', scale=sigTree.scale, ax=ax)
#
# ---> 17 n_sig1_SRhs, e = Hist(sigTree1.t6_X.m[sig1_SRhs_mask], bins=mBins, label='450, 300', scale=sigTree1.scale, ax=ax)
#
#      18 n_sig2_SRhs, e = Hist(sigTree2.t6_X.m[sig2_SRhs_mask], bins=mBins, label='500, 300', scale=sigTree1.scale, ax=ax)
#
#      19 n_sig4_SRhs, e = Hist(sigTree4.t6_X.m[sig4_SRhs_mask], bins=mBins, label='600, 400', scale=sigTree1.scale, ax=ax)
#
#
#
# NameError: name 'sigTree1' is not defined
# findfont: Font family ['TeX Gyre Heros'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['TeX Gyre Heros'] not found. Falling back to DejaVu Sans.
# ...

# %%
mH_bins = np.linspace(0,500,101)
fig, axs = plt.subplots(figsize=(25,10), nrows=1, ncols=3)

ax = axs[0]
# n_CR, b = Hist(sigTree.t6_higgs_m[:,0][sig_CR], bins=mH_bins, ax=ax, color='orangered', label='CR')
n_CR, b = Hist(sigTree.t6_higgs_m[:,0][sig_CR & (sigTree.nfound_t6 == 6)], bins=mH_bins, ax=ax, label='CR, 6 found')
n_CR, b = Hist(sigTree.t6_higgs_m[:,0][sig_CR & (sigTree.nfound_t6 == 5)], bins=mH_bins, ax=ax, label='CR, 5 found')
n_CR, b = Hist(sigTree.t6_higgs_m[:,0][sig_CR & (sigTree.nfound_t6 == 4)], bins=mH_bins, ax=ax, label='CR, 4 found')
n_CR, b = Hist(sigTree.t6_higgs_m[:,0][sig_CR & (sigTree.nfound_t6 == 3)], bins=mH_bins, ax=ax, label='CR, 3 found')
n_CR, b = Hist(sigTree.t6_higgs_m[:,0][sig_CR & (sigTree.nfound_t6 == 2)], bins=mH_bins, ax=ax, label='CR, 2 found')
n_CR, b = Hist(sigTree.t6_higgs_m[:,0][sig_CR & (sigTree.nfound_t6 == 1)], bins=mH_bins, ax=ax, label='CR, 1 found')
n_CR, b = Hist(sigTree.t6_higgs_m[:,0][sig_CR & (sigTree.nfound_t6 == 0)], bins=mH_bins, ax=ax, label='CR, 0 found')
# n_VR, b = Hist(sigTree.t6_higgs_m[:,0][sig_VR], bins=mH_bins, ax=ax, color='darkblue', label='VR')
# n_VR, b = Hist(sigTree.t6_higgs_m[:,0][sig_SR], bins=mH_bins, ax=ax, color='darkgreen', label='SR')
# ax.yaxis.set_major_formatter(FormatStrFormatter('%.2f'))
ax.set_xlabel(r'$m_1$ [GeV]')
ax.set_ylabel('Events')
# print(n_s.sum()/np.sqrt(n_b.sum()))

ax = axs[1]
# n_CR, b = Hist(sigTree.t6_higgs_m[:,1][sig_CR], bins=mH_bins, ax=ax,color='orangered', label='CR')
n_CR, b = Hist(sigTree.t6_higgs_m[:,1][sig_CR & (sigTree.nfound_t6 == 6)], bins=mH_bins, ax=ax, label='CR, 6 found')
n_CR, b = Hist(sigTree.t6_higgs_m[:,1][sig_CR & (sigTree.nfound_t6 == 5)], bins=mH_bins, ax=ax, label='CR, 5 found')
n_CR, b = Hist(sigTree.t6_higgs_m[:,1][sig_CR & (sigTree.nfound_t6 == 4)], bins=mH_bins, ax=ax, label='CR, 4 found')
n_CR, b = Hist(sigTree.t6_higgs_m[:,1][sig_CR & (sigTree.nfound_t6 == 3)], bins=mH_bins, ax=ax, label='CR, 3 found')
n_CR, b = Hist(sigTree.t6_higgs_m[:,1][sig_CR & (sigTree.nfound_t6 == 2)], bins=mH_bins, ax=ax, label='CR, 2 found')
n_CR, b = Hist(sigTree.t6_higgs_m[:,1][sig_CR & (sigTree.nfound_t6 == 1)], bins=mH_bins, ax=ax, label='CR, 1 found')
n_CR, b = Hist(sigTree.t6_higgs_m[:,1][sig_CR & (sigTree.nfound_t6 == 0)], bins=mH_bins, ax=ax, label='CR, 0 found')
# n_VR, b = Hist(sigTree.t6_higgs_m[:,1][sig_VR], bins=mH_bins, ax=ax,color='darkblue', label='VR')
# n_VR, b = Hist(sigTree.t6_higgs_m[:,1][sig_SR], bins=mH_bins, ax=ax,color='darkgreen', label='SR')
# ax.yaxis.set_major_formatter(FormatStrFormatter('%.2f'))
ax.set_xlabel(r'$m_2$ [GeV]')
ax.set_ylabel('Events')

ax = axs[2]
# n_s, b = Hist(sigTree.t6_higgs_m[:,2][sig_CR], bins=mH_bins, ax=ax, color='orangered', label='CR')
n_CR, b = Hist(sigTree.t6_higgs_m[:,2][sig_CR & (sigTree.nfound_t6 == 6)], bins=mH_bins, ax=ax, label='CR, 6 found')
n_CR, b = Hist(sigTree.t6_higgs_m[:,2][sig_CR & (sigTree.nfound_t6 == 5)], bins=mH_bins, ax=ax, label='CR, 5 found')
n_CR, b = Hist(sigTree.t6_higgs_m[:,2][sig_CR & (sigTree.nfound_t6 == 4)], bins=mH_bins, ax=ax, label='CR, 4 found')
n_CR, b = Hist(sigTree.t6_higgs_m[:,2][sig_CR & (sigTree.nfound_t6 == 3)], bins=mH_bins, ax=ax, label='CR, 3 found')
n_CR, b = Hist(sigTree.t6_higgs_m[:,2][sig_CR & (sigTree.nfound_t6 == 2)], bins=mH_bins, ax=ax, label='CR, 2 found')
n_CR, b = Hist(sigTree.t6_higgs_m[:,2][sig_CR & (sigTree.nfound_t6 == 1)], bins=mH_bins, ax=ax, label='CR, 1 found')
n_CR, b = Hist(sigTree.t6_higgs_m[:,2][sig_CR & (sigTree.nfound_t6 == 0)], bins=mH_bins, ax=ax, label='CR, 0 found')
# n_s, b = Hist(sigTree.t6_higgs_m[:,2][sig_VR], bins=mH_bins, ax=ax, color='darkblue', label='VR')
# n_s, b = Hist(sigTree.t6_higgs_m[:,2][sig_SR], bins=mH_bins, ax=ax, color='darkgreen', label='SR')
# ax.yaxis.set_major_formatter(FormatStrFormatter('%2.2f'))
ax.set_xlabel(r'$m_3$ [GeV]')
ax.set_ylabel('Events')

plt.tight_layout()

# %%
mH_bins = np.linspace(0,500,101)
fig, axs = plt.subplots(figsize=(25,10), nrows=1, ncols=3)

ax = axs[0]
# n_CR, b = Hist(sigTree.t6_higgs_m[:,0][sig_CR], bins=mH_bins, ax=ax, color='orangered', label='CR')
n_CR, b = Hist(sigTree.t6_higgs_m[:,0][sig_VR & (sigTree.nfound_t6 == 6)], bins=mH_bins, ax=ax, label='VR, 6 found')
n_CR, b = Hist(sigTree.t6_higgs_m[:,0][sig_VR & (sigTree.nfound_t6 == 5)], bins=mH_bins, ax=ax, label='VR, 5 found')
n_CR, b = Hist(sigTree.t6_higgs_m[:,0][sig_VR & (sigTree.nfound_t6 == 4)], bins=mH_bins, ax=ax, label='VR, 4 found')
n_CR, b = Hist(sigTree.t6_higgs_m[:,0][sig_VR & (sigTree.nfound_t6 == 3)], bins=mH_bins, ax=ax, label='VR, 3 found')
n_CR, b = Hist(sigTree.t6_higgs_m[:,0][sig_VR & (sigTree.nfound_t6 == 2)], bins=mH_bins, ax=ax, label='VR, 2 found')
n_CR, b = Hist(sigTree.t6_higgs_m[:,0][sig_VR & (sigTree.nfound_t6 == 1)], bins=mH_bins, ax=ax, label='VR, 1 found')
n_CR, b = Hist(sigTree.t6_higgs_m[:,0][sig_VR & (sigTree.nfound_t6 == 0)], bins=mH_bins, ax=ax, label='VR, 0 found')
# n_VR, b = Hist(sigTree.t6_higgs_m[:,0][sig_VR], bins=mH_bins, ax=ax, color='darkblue', label='VR')
# n_VR, b = Hist(sigTree.t6_higgs_m[:,0][sig_SR], bins=mH_bins, ax=ax, color='darkgreen', label='SR')
# ax.yaxis.set_major_formatter(FormatStrFormatter('%.2f'))
ax.set_xlabel(r'$m_1$ [GeV]')
ax.set_ylabel('Events')
# print(n_s.sum()/np.sqrt(n_b.sum()))

ax = axs[1]
# n_CR, b = Hist(sigTree.t6_higgs_m[:,1][sig_CR], bins=mH_bins, ax=ax,color='orangered', label='CR')
n_CR, b = Hist(sigTree.t6_higgs_m[:,1][sig_VR & (sigTree.nfound_t6 == 6)], bins=mH_bins, ax=ax, label='VR, 6 found')
n_CR, b = Hist(sigTree.t6_higgs_m[:,1][sig_VR & (sigTree.nfound_t6 == 5)], bins=mH_bins, ax=ax, label='VR, 5 found')
n_CR, b = Hist(sigTree.t6_higgs_m[:,1][sig_VR & (sigTree.nfound_t6 == 4)], bins=mH_bins, ax=ax, label='VR, 4 found')
n_CR, b = Hist(sigTree.t6_higgs_m[:,1][sig_VR & (sigTree.nfound_t6 == 3)], bins=mH_bins, ax=ax, label='VR, 3 found')
n_CR, b = Hist(sigTree.t6_higgs_m[:,1][sig_VR & (sigTree.nfound_t6 == 2)], bins=mH_bins, ax=ax, label='VR, 2 found')
n_CR, b = Hist(sigTree.t6_higgs_m[:,1][sig_VR & (sigTree.nfound_t6 == 1)], bins=mH_bins, ax=ax, label='VR, 1 found')
n_CR, b = Hist(sigTree.t6_higgs_m[:,1][sig_VR & (sigTree.nfound_t6 == 0)], bins=mH_bins, ax=ax, label='VR, 0 found')
# n_VR, b = Hist(sigTree.t6_higgs_m[:,1][sig_VR], bins=mH_bins, ax=ax,color='darkblue', label='VR')
# n_VR, b = Hist(sigTree.t6_higgs_m[:,1][sig_SR], bins=mH_bins, ax=ax,color='darkgreen', label='SR')
# ax.yaxis.set_major_formatter(FormatStrFormatter('%.2f'))
ax.set_xlabel(r'$m_2$ [GeV]')
ax.set_ylabel('Events')

ax = axs[2]
# n_s, b = Hist(sigTree.t6_higgs_m[:,2][sig_CR], bins=mH_bins, ax=ax, color='orangered', label='CR')
n_CR, b = Hist(sigTree.t6_higgs_m[:,2][sig_VR & (sigTree.nfound_t6 == 6)], bins=mH_bins, ax=ax, label='VR, 6 found')
n_CR, b = Hist(sigTree.t6_higgs_m[:,2][sig_VR & (sigTree.nfound_t6 == 5)], bins=mH_bins, ax=ax, label='VR, 5 found')
n_CR, b = Hist(sigTree.t6_higgs_m[:,2][sig_VR & (sigTree.nfound_t6 == 4)], bins=mH_bins, ax=ax, label='VR, 4 found')
n_CR, b = Hist(sigTree.t6_higgs_m[:,2][sig_VR & (sigTree.nfound_t6 == 3)], bins=mH_bins, ax=ax, label='VR, 3 found')
n_CR, b = Hist(sigTree.t6_higgs_m[:,2][sig_VR & (sigTree.nfound_t6 == 2)], bins=mH_bins, ax=ax, label='VR, 2 found')
n_CR, b = Hist(sigTree.t6_higgs_m[:,2][sig_VR & (sigTree.nfound_t6 == 1)], bins=mH_bins, ax=ax, label='VR, 1 found')
n_CR, b = Hist(sigTree.t6_higgs_m[:,2][sig_VR & (sigTree.nfound_t6 == 0)], bins=mH_bins, ax=ax, label='VR, 0 found')
# n_s, b = Hist(sigTree.t6_higgs_m[:,2][sig_VR], bins=mH_bins, ax=ax, color='darkblue', label='VR')
# n_s, b = Hist(sigTree.t6_higgs_m[:,2][sig_SR], bins=mH_bins, ax=ax, color='darkgreen', label='SR')
# ax.yaxis.set_major_formatter(FormatStrFormatter('%2.2f'))
ax.set_xlabel(r'$m_3$ [GeV]')
ax.set_ylabel('Events')

plt.tight_layout()

# %%
mH_bins = np.linspace(0,500,101)
fig, axs = plt.subplots(figsize=(25,10), nrows=1, ncols=3)

ax = axs[0]
# n_CR, b = Hist(sigTree.t6_higgs_m[:,0][sig_CR], bins=mH_bins, ax=ax, color='orangered', label='CR')
n_CR, b = Hist(sigTree.t6_higgs_m[:,0][sig_SR & (sigTree.nfound_t6 == 6)], bins=mH_bins, ax=ax, label='SR, 6 found')
n_CR, b = Hist(sigTree.t6_higgs_m[:,0][sig_SR & (sigTree.nfound_t6 == 5)], bins=mH_bins, ax=ax, label='SR, 5 found')
n_CR, b = Hist(sigTree.t6_higgs_m[:,0][sig_SR & (sigTree.nfound_t6 == 4)], bins=mH_bins, ax=ax, label='SR, 4 found')
n_CR, b = Hist(sigTree.t6_higgs_m[:,0][sig_SR & (sigTree.nfound_t6 == 3)], bins=mH_bins, ax=ax, label='SR, 3 found')
n_CR, b = Hist(sigTree.t6_higgs_m[:,0][sig_SR & (sigTree.nfound_t6 == 2)], bins=mH_bins, ax=ax, label='SR, 2 found')
n_CR, b = Hist(sigTree.t6_higgs_m[:,0][sig_SR & (sigTree.nfound_t6 == 1)], bins=mH_bins, ax=ax, label='SR, 1 found')
n_CR, b = Hist(sigTree.t6_higgs_m[:,0][sig_SR & (sigTree.nfound_t6 == 0)], bins=mH_bins, ax=ax, label='SR, 0 found')
# n_VR, b = Hist(sigTree.t6_higgs_m[:,0][sig_VR], bins=mH_bins, ax=ax, color='darkblue', label='VR')
# n_VR, b = Hist(sigTree.t6_higgs_m[:,0][sig_SR], bins=mH_bins, ax=ax, color='darkgreen', label='SR')
# ax.yaxis.set_major_formatter(FormatStrFormatter('%.2f'))
ax.set_xlabel(r'$m_1$ [GeV]')
ax.set_ylabel('Events')
# print(n_s.sum()/np.sqrt(n_b.sum()))

ax = axs[1]
# n_CR, b = Hist(sigTree.t6_higgs_m[:,1][sig_CR], bins=mH_bins, ax=ax,color='orangered', label='CR')
n_CR, b = Hist(sigTree.t6_higgs_m[:,1][sig_SR & (sigTree.nfound_t6 == 6)], bins=mH_bins, ax=ax, label='SR, 6 found')
n_CR, b = Hist(sigTree.t6_higgs_m[:,1][sig_SR & (sigTree.nfound_t6 == 5)], bins=mH_bins, ax=ax, label='SR, 5 found')
n_CR, b = Hist(sigTree.t6_higgs_m[:,1][sig_SR & (sigTree.nfound_t6 == 4)], bins=mH_bins, ax=ax, label='SR, 4 found')
n_CR, b = Hist(sigTree.t6_higgs_m[:,1][sig_SR & (sigTree.nfound_t6 == 3)], bins=mH_bins, ax=ax, label='SR, 3 found')
n_CR, b = Hist(sigTree.t6_higgs_m[:,1][sig_SR & (sigTree.nfound_t6 == 2)], bins=mH_bins, ax=ax, label='SR, 2 found')
n_CR, b = Hist(sigTree.t6_higgs_m[:,1][sig_SR & (sigTree.nfound_t6 == 1)], bins=mH_bins, ax=ax, label='SR, 1 found')
n_CR, b = Hist(sigTree.t6_higgs_m[:,1][sig_SR & (sigTree.nfound_t6 == 0)], bins=mH_bins, ax=ax, label='SR, 0 found')
# n_VR, b = Hist(sigTree.t6_higgs_m[:,1][sig_VR], bins=mH_bins, ax=ax,color='darkblue', label='VR')
# n_VR, b = Hist(sigTree.t6_higgs_m[:,1][sig_SR], bins=mH_bins, ax=ax,color='darkgreen', label='SR')
# ax.yaxis.set_major_formatter(FormatStrFormatter('%.2f'))
ax.set_xlabel(r'$m_2$ [GeV]')
ax.set_ylabel('Events')

ax = axs[2]
# n_s, b = Hist(sigTree.t6_higgs_m[:,2][sig_CR], bins=mH_bins, ax=ax, color='orangered', label='CR')
n_CR, b = Hist(sigTree.t6_higgs_m[:,2][(sigTree.nfound_t6 == 6) & (sig_SR)], bins=mH_bins, ax=ax, label='SR, 6 found')
n_CR, b = Hist(sigTree.t6_higgs_m[:,2][sig_SR & (sigTree.nfound_t6 == 5)], bins=mH_bins, ax=ax, label='SR, 5 found')
n_CR, b = Hist(sigTree.t6_higgs_m[:,2][sig_SR & (sigTree.nfound_t6 == 4)], bins=mH_bins, ax=ax, label='SR, 4 found')
n_CR, b = Hist(sigTree.t6_higgs_m[:,2][sig_SR & (sigTree.nfound_t6 == 3)], bins=mH_bins, ax=ax, label='SR, 3 found')
n_CR, b = Hist(sigTree.t6_higgs_m[:,2][sig_SR & (sigTree.nfound_t6 == 2)], bins=mH_bins, ax=ax, label='SR, 2 found')
n_CR, b = Hist(sigTree.t6_higgs_m[:,2][sig_SR & (sigTree.nfound_t6 == 1)], bins=mH_bins, ax=ax, label='SR, 1 found')
n_CR, b = Hist(sigTree.t6_higgs_m[:,2][sig_SR & (sigTree.nfound_t6 == 0)], bins=mH_bins, ax=ax, label='SR, 0 found')
# n_s, b = Hist(sigTree.t6_higgs_m[:,2][sig_VR], bins=mH_bins, ax=ax, color='darkblue', label='VR')
# n_s, b = Hist(sigTree.t6_higgs_m[:,2][sig_SR], bins=mH_bins, ax=ax, color='darkgreen', label='SR')
# ax.yaxis.set_major_formatter(FormatStrFormatter('%2.2f'))
ax.set_xlabel(r'$m_3$ [GeV]')
ax.set_ylabel('Events')

plt.tight_layout()

# %%
fig, ax = plt.subplots()

xmin = mX - 0.3*mX
xmax = mX + 0.15*mX
nbins = 100

fig.suptitle("Signal Region, high score")

ax.set_title(sigTree.sample, loc='right')

## How many signal jets found?
n_sig_SRhs, e = Hist(sig_X.m[sig_SRhs_mask], bins=mBins, label='All', scale=sigTree.scale, ax=ax)
n, e = Hist(sig_X.m[sig_SRhs_mask & (ak.sum(sigTree.t6_jet_signalId > -1, axis=1) == 6)], bins=np.linspace(250,1250,nbins), label='6 jets found', scale=sigTree.scale, ax=ax, density=1, color='C1')
N = n.sum()
n, e = Hist(sig_X.m[sig_SRhs_mask & (ak.sum(sigTree.t6_jet_signalId > -1, axis=1) == 5)], bins=np.linspace(250,1250,nbins), label='5 jets found', scale=sigTree.scale, ax=ax, density=1, color='C2')
N += n.sum()
n, e = Hist(sig_X.m[sig_SRhs_mask & (ak.sum(sigTree.t6_jet_signalId > -1, axis=1) == 4)], bins=np.linspace(250,1250,nbins), label='4 jets found', scale=sigTree.scale, ax=ax, density=1, color='C3')
N += n.sum()

print(n_sig_SRhs.sum())
print(N)
print(f"{(n_sig_SRhs.sum()-N)/n_sig_SRhs.sum()*100:.1f}%")

ax.set_xlabel(r'Six Jet $m_\mathrm{inv}$ [GeV]')
ax.set_ylabel('Fraction of Events')

# fig.savefig(f'plots/{sigTree.mXmY}_v_dat_minv6.pdf')
# Out:
# 1712.5466666666675
# 2.9999999999999996
# 99.8%
# Text(0, 1, 'Fraction of Events')

# %%
fig, ax = plt.subplots()

xmin = mX - 0.3*mX
xmax = mX + 0.15*mX
nbins = 100

fig.suptitle("Signal Region")

ax.set_title(sigTree.sample, loc='right')

## How many signal jets found?
n, e = Hist(sigTree.t6_jet_btagsum[sig_SRhs_mask & (ak.sum(sigTree.t6_jet_signalId > -1, axis=1) == 6)]/6, bins=np.linspace(0.5,1,nbins), label='6 jets found', scale=sigTree.scale, ax=ax, density=1, color='C1')
N = n.sum()
n, e = Hist(sigTree.t6_jet_btagsum[sig_SRhs_mask & (ak.sum(sigTree.t6_jet_signalId > -1, axis=1) == 5)]/6, bins=np.linspace(0.5,1,nbins), label='5 jets found', scale=sigTree.scale, ax=ax, density=1, color='C2')
N += n.sum()
n, e = Hist(sigTree.t6_jet_btagsum[sig_SRhs_mask & (ak.sum(sigTree.t6_jet_signalId > -1, axis=1) == 4)]/6, bins=np.linspace(0.5,1,nbins), label='4 jets found', scale=sigTree.scale, ax=ax, density=1, color='C3')
N += n.sum()

print(n_sig_SRhs.sum())
print(N)
print(f"{(n_sig_SRhs.sum()-N)/n_sig_SRhs.sum()*100:.1f}%")

ax.set_xlabel(r'Six Jet b-tag Sum')
ax.set_ylabel('Fraction of Events')

# fig.savefig(f'plots/{sigTree.mXmY}_v_dat_minv6.pdf')
# Out:
# 1621.4723513625886
# 3.0
# 99.8%
# Text(0, 1, 'Fraction of Events')

# %%
fig, ax = plt.subplots()

xmin = mX - 0.3*mX
xmax = mX + 0.15*mX
nbins = 100
bins = np.linspace(0,150,nbins)

fig.suptitle("Signal Region")

ax.set_title(sigTree.sample, loc='right')

## How many signal jets found?
n, e = Hist(sigTree.t6_jet_pt[:,5][sig_SRhs_mask & (ak.sum(sigTree.t6_jet_signalId > -1, axis=1) == 6)]/6, bins=bins, label='6 jets found', scale=sigTree.scale, ax=ax, density=1, color='C1')
N = n.sum()
n, e = Hist(sigTree.t6_jet_pt[:,5][sig_SRhs_mask & (ak.sum(sigTree.t6_jet_signalId > -1, axis=1) == 5)]/6, bins=bins, label='5 jets found', scale=sigTree.scale, ax=ax, density=1, color='C2')
N += n.sum()
n, e = Hist(sigTree.t6_jet_pt[:,5][sig_SRhs_mask & (ak.sum(sigTree.t6_jet_signalId > -1, axis=1) == 4)]/6, bins=bins, label='4 jets found', scale=sigTree.scale, ax=ax, density=1, color='C3')
N += n.sum()

print(n_sig_SRhs.sum())
print(N)
print(f"{(n_sig_SRhs.sum()-N)/n_sig_SRhs.sum()*100:.1f}%")

ax.set_xlabel(r'Jet 6 $p_T$ [GeV]')
ax.set_ylabel('Fraction of Events')

#################################################
fig, ax = plt.subplots()

xmin = mX - 0.3*mX
xmax = mX + 0.15*mX
nbins = 100
bins = np.linspace(0,150,nbins)

fig.suptitle("Signal Region")

ax.set_title(sigTree.sample, loc='right')

## How many signal jets found?
n, e = Hist(sigTree.t6_jet_pt[:,5][sig_SRhs_mask & (ak.sum(sigTree.t6_jet_signalId > -1, axis=1) == 6)]/6, bins=bins, label='6 jets found', scale=sigTree.scale, ax=ax, density=1, color='C1')
N = n.sum()
n, e = Hist(sigTree.t6_jet_pt[:,5][sig_SRhs_mask & (ak.sum(sigTree.t6_jet_signalId > -1, axis=1) == 5)]/6, bins=bins, label='5 jets found', scale=sigTree.scale, ax=ax, density=1, color='C2')
N += n.sum()
n, e = Hist(sigTree.t6_jet_pt[:,5][sig_SRhs_mask & (ak.sum(sigTree.t6_jet_signalId > -1, axis=1) == 4)]/6, bins=bins, label='4 jets found', scale=sigTree.scale, ax=ax, density=1, color='C3')
N += n.sum()

ax.set_yscale('log')

print(n_sig_SRhs.sum())
print(N)
print(f"{(n_sig_SRhs.sum()-N)/n_sig_SRhs.sum()*100:.1f}%")

ax.set_xlabel(r'Jet 6 $p_T$ [GeV]')
ax.set_ylabel('Fraction of Events')

# fig.savefig(f'plots/{sigTree.mXmY}_v_dat_minv6.pdf')
# Out:
# 1621.4723513625886
# 2.9999999999999996
# 99.8%
# 1621.4723513625886
# 2.9999999999999996
# 99.8%
# Text(0, 1, 'Fraction of Events')

# %%
fig, ax = plt.subplots()

xmin = mX - 0.3*mX
xmax = mX + 0.15*mX
nbins = 100
bins = np.linspace(0,0.2,nbins)

fig.suptitle("Signal Region")

ax.set_title(sigTree.sample, loc='right')

## How many signal jets found?
n, e = Hist(sigTree.t6_jet_btag[:,5][sig_SRhs_mask & (ak.sum(sigTree.t6_jet_signalId > -1, axis=1) == 6)]/6, bins=bins, label='6 jets found', scale=sigTree.scale, ax=ax, density=1, color='C1')
N = n.sum()
n, e = Hist(sigTree.t6_jet_btag[:,5][sig_SRhs_mask & (ak.sum(sigTree.t6_jet_signalId > -1, axis=1) == 5)]/6, bins=bins, label='5 jets found', scale=sigTree.scale, ax=ax, density=1, color='C2')
N += n.sum()
n, e = Hist(sigTree.t6_jet_btag[:,5][sig_SRhs_mask & (ak.sum(sigTree.t6_jet_signalId > -1, axis=1) == 4)]/6, bins=bins, label='4 jets found', scale=sigTree.scale, ax=ax, density=1, color='C3')
N += n.sum()

print(n_sig_SRhs.sum())
print(N)
print(f"{(n_sig_SRhs.sum()-N)/n_sig_SRhs.sum()*100:.1f}%")

ax.set_xlabel(r'Jet 6 b-tag')
ax.set_ylabel('Fraction of Events')

ax.ticklabel_format(style='sci', axis='x', scilimits=(-5,2))
# ax.set_xticklabels()
# plt.ticklabel_format(style='sci', axis='x', scilimits=(0,0))
# Out:
# 1621.4723513625886
# 2.999999999999999
# 99.8%
