# %%
# %load_ext autoreload
# %autoreload 2

import os
import sys
import git

import uproot as ut
import awkward as ak
import numpy as np
import math
import vector
import sympy as sp

import re
from tqdm import tqdm
import timeit

sys.path.append( git.Repo('.', search_parent_directories=True).working_tree_dir )
from utils import *

# %%
signal_tree = Tree(fc.preselected.NMSSM_MX_700_MY_400)
signal_presel = Selection(tree,variable="jet_pt")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-48-e0ecad6dd7d6> in <module>
#       1 signal_tree = Tree(fc.preselected.NMSSM_MX_700_MY_400)
# ----> 2 signal_presel = Selection(tree,variable="jet_pt")
#
# NameError: name 'tree' is not defined

# %%
signal_study.njet(signal_presel)

# %%
signal_study.jets(signal_presel)

# %%
wplist = jet_btagWP+[1]
signal_presel_btagwp = [ signal_presel.chosen_jets(cuts=dict(btagcut=jet_btagWP[wp],btagcut_invert=wplist[wp+1])) for wp in range(1,4) ]

# %%
for btagwp in signal_presel_btagwp: signal_study.jets_2d_ordered(btagwp,compare=1,njets=1)

# %%
signal_selec = jet_cut(signal_tree)

# %%
signal_study.jets(signal_selec)

# %%
print(signal_presel)
# Out:
# --- all Signal ---
# Event Efficiency:   1.0
# Selected Purity(6): 0.46
# Passed Jet S/T:     0.85

# %%
print(signal_selec)
# Out:
# --- (all Signal & all signal selection) ---
# Event Efficiency:   0.92
# Selected Purity(6): 0.48
# Passed Jet S/T:     0.86
