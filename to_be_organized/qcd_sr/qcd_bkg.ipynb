# %%
# %load_ext autoreload
# %autoreload 2

import os
import sys
import git

import uproot as ut
import awkward as ak
import numpy as np
import math
import vector
import sympy as sp

import re
from tqdm import tqdm
import timeit

sys.path.append( git.Repo('.', search_parent_directories=True).working_tree_dir )
from utils import *

# %%
filename = "../mc/QCD_Pt_1000to1400_TuneCP5_13TeV_pythia8.root"
tree = Tree(filename,is_signal=False,sample="QCD_Pt_1000to1400")
preselection = Selection(tree,tag="preselection")
print(preselection)
# Out:
# --- all preselection ---
# Event Efficiency:   1.0

# %%
ijets_study(preselection,scaled=True)
# Out:
# --- all preselection ---
# Event Efficiency:   1.0
