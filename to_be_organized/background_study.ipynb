# %%
# %load_ext autoreload
# %autoreload 2

import os
import sys
import git

import uproot as ut
import awkward as ak
import numpy as np
import math
import vector
import sympy as sp

import re
from tqdm import tqdm
import timeit

sys.path.append( git.Repo('.', search_parent_directories=True).working_tree_dir )
from utils import *

# %%
trees = [ Tree(sample) for sample in [fc.sr.QCD_B_List,fc.sr.NMSSM_MX_700_MY_400] ]

# %%
study.cutflow(trees,log=1)

# %%
study.njets(trees,density=1)

# %%
study.ijets(trees,njets=4,density=1)

# %%
study.higgs(trees,["QCD","Signal"],density=1)
